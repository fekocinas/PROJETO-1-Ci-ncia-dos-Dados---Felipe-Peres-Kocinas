# %% [markdown]
# #### Projeto 1 - Ciência dos Dados

# %% [markdown]
# ### Felipe Peres Kocinas - 2ºA

# %% [markdown]
# # Introdução:
#
# ### O que o IDH representa?
#
# O IDH (Índice de Desenvolvimento Humano) é um dado calculado pelo Programa das Nações Unidas para o Desenvolvimento (PNUD), órgão da ONU,e é formado a partir de três fatores: expectativa de vida, renda per capita e anos médios de estudo e anos esperados de escolaridade.
#
# ### Coleta dos dados:
#
# Os dados foram coletados no website Gapminder e escolhidos para serem comparados ao IDH, tais foram: a porcentagem da população que vive em regiões urbanas e o total do PIB (Produto Interno Bruto) em dólares de cada país.
#
# A partir desses dados foi realizada a seguinte pergunta a ser respondida nesse documento.
# ### Pergunta:
# O IDH dos países é influênciado pelo índice populacional das cidades e se o PIB dos países for baixo é possível seu IDH ser elevado?

# %% [markdown]
# O motivo da escolha da pergunta foi porque poderia analisar situações diferentes da realidade brasileira, pelo fato de que o Brasil é um país majoritariamente urbano e possui um PIB muito alto.
#
# A minha pergunta foi formulado a partir da hipótese de que países mais urbanizados,  passaram pelo processo de Urbanização, e isso possibilitou o aumento da geração de trabalhos, o que impulsionou a economia, e o aumento do acesso a escolas e hospitais, fatores que são fortemente ligados aos dados que compõem o IDH, e a segunda parte da pergunta foi formulada para saciar uma curiosidade sobre países com baixo PIB, para descobrir a tendência de seus IDHs.

# %% [markdown]
# ### Código:
#
# A seguir foram implementados os códigos necessários para que fosse possível abrir e juntar em jupyter com o uso da biblioteca pandas os dados escolhidos e que foram baixados do Gapminder. Também foram executados códigos para selecionar os dados apenas do ano de 2014 e atribuir títulos as colunas.

# %%
# %matplotlib inline
#------Import das bibliotecas-----
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#------abrindo os arquivos do excel-------
IDH = pd.read_excel('hdi_human_development_index.xlsx')
PIB = pd.read_excel('total_gdp_us_inflation_adjusted.xlsx')
PopUrb = pd.read_excel('urban_population_percent_of_total (1).xlsx')

# %%
#------selecinando os dados desejados de cada arquivo------
IDH_2014 = IDH.loc[:, ["geo", 2014]]
PIB_2014 = PIB.loc[:, ["geo", 2014]]
PopUrb_2014 = PopUrb.loc[:, ["geo", 2014]]

# %%
#-------selecionando a coluna do index-------
IDH_idx = IDH_2014.set_index('geo')
PIB_idx = PIB_2014.set_index('geo')
PopUrb_idx = PopUrb_2014.set_index('geo')

# %%
#------unindos os arquivos e mudando o nome das colunas-------
df = IDH_idx.join(PopUrb_idx, how='inner', lsuffix='_IDH', rsuffix='_% PopUrb')
df["IDH"]=df.pop("2014_IDH")
df["% da População Urbana"]=df.pop('2014_% PopUrb')
dados = df.join(PIB_idx, how='inner')
dados["PIB total em dólares"]=dados.pop(2014)
print("Todos os dados obtidos estão a seguir:")
dados1 = dados.dropna()
dados1
# Out:
# Todos os dados obtidos estão a seguir:
#                                   IDH  % da População Urbana  \
# geo
# Afghanistan                     0.479                  26.30
# Albania                         0.762                  56.40
# Algeria                         0.743                  70.10
# Andorra                         0.857                  85.60
# Angola                          0.531                  43.30
# Antigua and Barbuda             0.784                  24.20
# Argentina                       0.826                  91.60
# Armenia                         0.741                  62.80
# Australia                       0.937                  89.30
# Austria                         0.892                  65.90
# Azerbaijan                      0.758                  54.40
# Bahamas                         0.790                  82.80
# Bahrain                         0.823                  88.70
# Bangladesh                      0.575                  33.50
# Barbados                        0.794                  31.60
# Belarus                         0.798                  76.30
# Belgium                         0.895                  97.80
# Belize                          0.706                  44.10
# Benin                           0.481                  43.50
# Bhutan                          0.604                  37.90
# Bolivia                         0.671                  68.10
# Bosnia and Herzegovina          0.747                  39.60
# Botswana                        0.698                  57.20
# Brazil                          0.754                  85.40
# Brunei                          0.864                  76.90
# Bulgaria                        0.792                  73.60
# Burkina Faso                    0.399                  29.00
# Burundi                         0.406                  11.80
# Cambodia                        0.558                  20.50
# Cameroon                        0.514                  53.80
# ...                               ...                    ...
# St. Lucia                       0.735                  18.50
# St. Vincent and the Grenadines  0.720                  50.20
# Sudan                           0.488                  33.60
# Suriname                        0.723                  66.10
# Swaziland                       0.541                  21.30
# Sweden                          0.909                  85.70
# Switzerland                     0.938                  73.80
# Tajikistan                      0.625                  26.70
# Tanzania                        0.519                  30.90
# Thailand                        0.738                  49.20
# Timor-Leste                     0.603                  32.10
# Togo                            0.484                  39.50
# Tonga                           0.718                  23.60
# Trinidad and Tobago             0.779                   8.55
# Tunisia                         0.723                  66.60
# Turkey                          0.764                  72.90
# Turkmenistan                    0.688                  49.70
# Uganda                          0.488                  15.80
# Ukraine                         0.748                  69.50
# United Arab Emirates            0.836                  85.30
# United Kingdom                  0.908                  82.30
# United States                   0.918                  81.40
# Uruguay                         0.794                  95.20
# Uzbekistan                      0.697                  36.30
# Vanuatu                         0.598                  25.80
# Venezuela                       0.769                  88.90
# Vietnam                         0.678                  33.00
# Yemen                           0.499                  34.00
# Zambia                          0.576                  40.50
# Zimbabwe                        0.507                  32.50
#
#                                 PIB total em dólares
# geo
# Afghanistan                             2.060000e+10
# Albania                                 1.280000e+10
# Algeria                                 1.830000e+11
# Andorra                                 3.230000e+09
# Angola                                  1.010000e+11
# Antigua and Barbuda                     1.230000e+09
# Argentina                               4.440000e+11
# Armenia                                 1.110000e+10
# Australia                               1.280000e+12
# Austria                                 4.100000e+11
# Azerbaijan                              5.840000e+10
# Bahamas                                 8.060000e+09
# Bahrain                                 2.990000e+10
# Bangladesh                              1.470000e+11
# Barbados                                4.500000e+09
# Belarus                                 6.310000e+10
# Belgium                                 5.010000e+11
# Belize                                  1.550000e+09
# Benin                                   8.580000e+09
# Bhutan                                  1.940000e+09
# Bolivia                                 2.450000e+10
# Bosnia and Herzegovina                  1.780000e+10
# Botswana                                1.640000e+10
# Brazil                                  2.420000e+12
# Brunei                                  1.370000e+10
# Bulgaria                                5.270000e+10
# Burkina Faso                            1.120000e+10
# Burundi                                 2.400000e+09
# Cambodia                                1.490000e+10
# Cameroon                                3.180000e+10
# ...                                              ...
# St. Lucia                               1.410000e+09
# St. Vincent and the Grenadines          7.090000e+08
# Sudan                                   6.930000e+10
# Suriname                                4.900000e+09
# Swaziland                               5.160000e+09
# Sweden                                  5.190000e+11
# Switzerland                             6.260000e+11
# Tajikistan                              7.460000e+09
# Tanzania                                4.090000e+10
# Thailand                                3.820000e+11
# Timor-Leste                             1.080000e+09
# Togo                                    3.840000e+09
# Tonga                                   3.790000e+08
# Trinidad and Tobago                     2.280000e+10
# Tunisia                                 4.750000e+10
# Turkey                                  1.030000e+12
# Turkmenistan                            3.500000e+10
# Uganda                                  2.500000e+10
# Ukraine                                 1.340000e+11
# United Arab Emirates                    3.540000e+11
# United Kingdom                          2.640000e+12
# United States                           1.620000e+13
# Uruguay                                 4.740000e+10
# Uzbekistan                              5.370000e+10
# Vanuatu                                 7.530000e+08
# Venezuela                               4.210000e+11
# Vietnam                                 1.450000e+11
# Yemen                                   2.890000e+10
# Zambia                                  2.530000e+10
# Zimbabwe                                1.450000e+10
#
# [183 rows x 3 columns]

# %% [markdown]
# # Gráfico 1 -  A porcentagem da população urbana pelo IDH

# %%
dados1.plot.scatter(x="IDH", y="% da População Urbana", grid=True, title="A porcentagem da população urbana pelo IDH")

# %% [markdown]
# # Gráfico 2 - O PIB total em dólares pelo IDH

# %%
dados1.plot.scatter(x="IDH", y="PIB total em dólares", grid=True, title="PIB total em dólares pelo IDH",loglog=True)

# %%
dados1.describe()
# Out:
#               IDH  % da População Urbana  PIB total em dólares
# count  183.000000             183.000000          1.830000e+02
# mean     0.696699              56.514481          3.960714e+11
# std      0.154012              23.128887          1.483361e+12
# min      0.347000               8.550000          1.730000e+08
# 25%      0.575000              37.750000          8.265000e+09
# 50%      0.729000              57.000000          2.950000e+10
# 75%      0.804500              76.050000          1.950000e+11
# max      0.948000             100.000000          1.620000e+13

# %%
dados1.corr()
# Out:
#                             IDH  % da População Urbana  PIB total em dólares
# IDH                    1.000000               0.701326              0.251649
# % da População Urbana  0.701326               1.000000              0.207242
# PIB total em dólares   0.251649               0.207242              1.000000

# %% [markdown]
# # Conclusão:

# %% [markdown]
# ## Conclusões sobre o Gráfico 1:
#
# A partir do gráfico 1 é possível observar que países a partir de 80% da sua população nas cidades possuem IDHs próximos ou acima de 0.8 e que países com índices rurais elevados possuem IDHs variados, porém com uma tendência a serem pequenos. Assim pode-se concluir que o r calculado que é igual a 0.70 realmente tem indicios de correlação positiva entre os dados.
#
# O processo de Urbanização no qual diversos países passaram, possibilitou o aumento da geração de trabalhos, o que impulsionou a economia, e o aumento do acesso a escolas e hospitais, fatores que são fortemente ligados aos dados que compõem o IDH.

# %% [markdown]
# ## Conclusões sobre o Gráfico 2:
#
# Nesse caso é possível observar que há pouca correlação entre os dados, pois PIBs elevados dependem certamente do tamanho dos países geograficamente e populacionalmente, logo terá países com PIBs baixos, porém com IDH alto. Mesmo assim, pode-se observar que a faixa indicativa de IDH baixo não possui países com os maiores PIBs do mundo.
